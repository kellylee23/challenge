# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lis = input()
n= len(lis)

count=0

for i in range(n-1):
    for j in range(i+1, n-1):
        if lis[i] == '(' and lis[i+1]=='(' and lis[j]==')' and lis[j+1]==')':
            count+=1
print(count)
